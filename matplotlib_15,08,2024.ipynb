# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
x = np.arange(0, 30, 0.2)
fig, ax = plt.subplots(figsize=(14, 8))
ax.plot(x, x-1, color = "r", linewidth = 1, linestyle = "-")
ax.plot(x, x-2, color = "green", lw = 2, ls = "-.")
ax.plot(x, x-3, color = "cyan", lw = 3, ls = ":")
ax.plot(x, x-4, color = "m", lw = 4, ls = "--")
plt.show()

# %%
x = np.arange(-50, 50)
y1 = np.power(x, 2)
y2 = np.power(x, 3)
y3 = np.sin(x)
y4 = np.cos(x)
y5 = np.tan(x)
y6 = np.tanh(x)
y7 = np.sinh(x)
y8 = np.cosh(x)
y9 = np.exp(x)
fig1, ax1 = plt.subplots(nrows = 3, ncols = 3, figsize= (20, 20))
ax1[0, 0].plot(x, y1, "tab:blue") # set the color of line chart
ax1[0, 0].set_title("Square Function") # setting title of subplot
ax1[0, 0].set_xlabel("X", fontsize = 18)
ax1[0, 0].set_ylabel("Y", fontsize = 18)
ax1[0, 1].plot(x, y2, "tab:orange") # set the color of line chart
ax1[0, 1].set_title("Cubic Function") # setting title of subplot
ax1[0, 1].set_xlabel("X", fontsize = 18)
ax1[0, 1].set_ylabel("Y", fontsize = 18)
ax1[0, 2].plot(x, y3, "tab:green") # set the color of line chart
ax1[0, 2].set_title("Sine Function") # setting title of subplot
ax1[0, 2].set_xlabel("X", fontsize = 18)
ax1[0, 2].set_ylabel("Y", fontsize = 18)
ax1[1, 0].plot(x, y4, "r-") # set the color of line chart
ax1[1, 0].set_title("Cosine Function") # setting title of subplot
ax1[1, 0].set_xlabel("X", fontsize = 18)
ax1[1, 0].set_ylabel("Y", fontsize = 18)
ax1[1, 1].plot(x, y5, "b-") # set the color of line chart
ax1[1, 1].set_title("Tangent Function") # setting title of subplot
ax1[1, 1].set_xlabel("X", fontsize = 18)
ax1[1, 1].set_ylabel("Y", fontsize = 18)
ax1[1, 2].plot(x, y6, "g-") # set the color of line chart
ax1[1, 2].set_title("Hyperbolic Tangent Function") # setting title of subplot
ax1[1, 2].set_xlabel("X", fontsize = 18)
ax1[1, 2].set_ylabel("Y", fontsize = 18)
ax1[2, 0].plot(x, y7, "m-") # set the color of line chart
ax1[2, 0].set_title("Hyperbolic Sine Function") # setting title of subplot
ax1[2, 0].set_xlabel("X", fontsize = 18)
ax1[2, 0].set_ylabel("Y", fontsize = 18)
ax1[2, 1].plot(x, y8, "y*") # set the color of line chart
ax1[2, 1].set_title("Hyperbolic Cosine Function") # setting title of subplot
ax1[2, 1].set_xlabel("X", fontsize = 18)
ax1[2, 1].set_ylabel("Y", fontsize = 18)
ax1[2, 2].plot(x, y9, "kv") # set the color of line chart
ax1[2, 2].set_title("Exp Function") # setting title of subplot
ax1[2, 2].set_xlabel("X", fontsize = 18)
ax1[2, 2].set_ylabel("Y", fontsize = 18)
plt.show()

# %% [markdown]
# ## Default değerlere dönme

# %%
mpl.rcParams.update(mpl.rcParamsDefault)

# %% [markdown]
# ## 3.5 Scotter Plot

# %%
x= np.array([15,17,18,17,12,17,12,19,14,11,12,19,16,13])
y= np.array([99,86,87,88,81,86,93,87,94,78,77,85,86,85])
plt.scatter(x, y)
plt.show()
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
tips = sns.load_dataset("tips")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips.tail()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %%
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
tips.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
tips.describe().T
# Out:
#             count       mean       std   min      25%     50%      75%    max
# total_bill  244.0  19.785943  8.902412  3.07  13.3475  17.795  24.1275  50.81
# tip         244.0   2.998279  1.383638  1.00   2.0000   2.900   3.5625  10.00
# size        244.0   2.569672  0.951100  1.00   2.0000   2.000   3.0000   6.00

# %%
plt.scatter(tips["total_bill"] , tips["tip"]);

# %%
plt.scatter(tips.total_bill , tips.tip);

# %%
fig ,ax=plt.subplots()
ax.bar(tips.sex , tips.tip);

# %%
fig ,ax=plt.subplots()
ax.barh(tips.sex , tips.tip);

# %%
fig ,ax=plt.subplots()
ax.bar(tips.day , tips.total_bill);

# %% [markdown]
# ## 3.6 Günlük Kazanç Bulma

# %%
tips.groupby("day")[["total_bill", "tip", "size"]].sum()
# Out:
# C:\Users\Didem Organ\AppData\Local\Temp\ipykernel_11044\1662578951.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   tips.groupby("day")[["total_bill", "tip", "size"]].sum()
#       total_bill     tip  size
# day
# Thur     1096.33  171.83   152
# Fri       325.88   51.96    40
# Sat      1778.40  260.40   219
# Sun      1627.16  247.39   216

# %%
# Sayısal verilerin seçilmesi
numeric_tips = tips[["total_bill", "day"]]
# Günler bazında "total_bill" toplamlarının seçilmesi
day_of_total_bill_sum = numeric_tips.groupby("day")["total_bill"].sum()
# Bar Grafiği için günler ve toplamlarının alınması 
days = day_of_total_bill_sum.index
total_bills = day_of_total_bill_sum.values
# Bar Grafiğin çizilmesi
fig, ax = plt.subplots(figsize = (8,6))
ax.bar(days, total_bills);
# Out:
# C:\Users\Didem Organ\AppData\Local\Temp\ipykernel_11044\1113192979.py:4: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   day_of_total_bill_sum = numeric_tips.groupby("day")["total_bill"].sum()

# %%
fig, ax = plt.subplots(figsize = (8,6))
ax.bar(days, total_bills);
ax.set_title("Total Bill by Day")
ax.set_xlabel("Day")
ax.set_ylabel("Total Bill")
plt.show()

# %% [markdown]
# ## 3.7 Pie Chart

# %%
x=np.array([100,100,100,100])
mylabels=("Apples" , "Bananas" , "Cherries" , "Lemon")

plt.figure(figsize =(10,8))
plt.pie(x , labels = mylabels , labeldistance = 0.5 , autopct = "%.2f") 
plt.show()

# %%
x=np.array([100,100,100,100])
mylabels=("Apples" , "Bananas" , "Cherries" , "Lemon")
myexplode = [0.8 ,0 ,0, 0] 
plt.figure(figsize =(10,8))
plt.pie(x , labels = mylabels , labeldistance = 0.5 , autopct = "%.2f" , explode=myexplode) 
plt.show()

# %%
x=np.array([100,100,100,100])
mylabels=("Apples" , "Bananas" , "Cherries" , "Lemon")
myexplode = [0.4 ,0 ,0.2, 0] 
plt.figure(figsize =(10,8))
plt.pie(x , labels = mylabels , labeldistance = 0.5 , autopct = "%.2f" , explode=myexplode) 
plt.show()

# %%
# saat yönünün tersine döner.

# %%
x=np.array([100,100,100,100])
mylabels=("Apples" , "Bananas" , "Cherries" , "Lemon")
myexplode = [0.8 ,0 ,0, 0] 

plt.figure(figsize =(10,8))
plt.pie(x , labels = mylabels , labeldistance = 0.5 , autopct = "%.2f"  ,startangle = 90) 
plt.show()

# %%
x=np.array([100,100,100,100])
mylabels=("Apples" , "Bananas" , "Cherries" , "Lemon")
myexplode = [0.8 ,0 ,0, 0] 

plt.figure(figsize =(10,8))
plt.pie(x , labels = mylabels , labeldistance = 0.5 , autopct = "%.2f"  ,startangle = 50) 
plt.show()

# %%
x=np.array([100,100,100,100])
mylabels=("Apples" , "Bananas" , "Cherries" , "Lemon")
myexplode = [0.8 ,0 ,0, 0] 

plt.figure(figsize =(10,8))
plt.pie(x , 
        labels = mylabels , 
        labeldistance = 0.5 , 
        autopct = "%.2f" ,
        startangle = 100) 
plt.show()

# %%
plt.figure(figsize = (10,8))
color_list = ["gold" , "yellowgreen" , "lightcoral" , "lightskyblue"]

y=np.array([25,35,25,15])
mylabels=("Apples" , "Bananas" , "Cherries" , "Lemon")
myexplode = [0.5 ,0 ,0, 0] 

plt.figure(figsize =(10,8))
plt.pie(y , 
        labels = mylabels , 
        labeldistance = 0.5 , 
        autopct = "%.1f" ,
        startangle = 90,
        shadow = True,
       pctdistance = 0.3,
       colors = color_list,
       explode = myexplode) 

plt.legend(loc = (1))
plt.show()

# %%
plt.figure(figsize = (10,8))
sex_counts = tips["sex"].value_counts()
color_list = ["lightskyblue" , "lightcoral"]

y=np.array([25,35,25,15])
mylabels=("Apples" , "Bananas" , "Cherries" , "Lemon")
myexplode = [0.1 ,0] 

plt.figure(figsize =(10,8))
plt.pie(sex_counts , 
        labels = sex_counts.index, 
        labeldistance = 0.4 , 
        autopct = "%.1f" ,
        startangle = 140,
        shadow = True,
       pctdistance = 0.5,
       colors = color_list,
       explode = myexplode) 

plt.legend(loc = (1))
plt.show()

# %%
#data setinden pie chart oluşturduk

# %% [markdown]
# # <p style="background-color:green;font-family:newtimeroman;font-size:200%;color:white;text-align:center;border-radius:20px 20px;"><b>Matplotlib Notebook</b></p>
# ![](https://www.techproeducation.com/logo/headerlogo.svg)
#
# <b>Yeniliklerden ilk siz haberdar olmak istiyorsanız lütfen bizi takip etmeyi unutmayın </b>[YouTube](https://www.youtube.com/c/techproeducation) | [Instagram](https://www.instagram.com/techproeducation) | [Facebook](https://www.facebook.com/techproeducation) | [Telegram](https://t.me/joinchat/HH2qRvA-ulh4OWbb) | [Watsapp](https://api.whatsapp.com/send/?phone=%2B15853042959&text&type=phone_number&app_absent=0) | [Linkedin](https://www.linkedin.com/company/techproeducation/mycompany/) |
