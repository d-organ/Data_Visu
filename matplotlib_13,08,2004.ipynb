# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
#shift tab tab

# %%
#plt.show() demez isek daha çok ekran çıktısı alıyoruz. alan kaplamaması için bu kodu kullanalım.

# %%
plt.plot(x, y)
plt.xticks(np.arange(0, 10, 1))
plt.yticks(np.arange(0, 19, 2))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 plt.plot(x, y)
#       2 plt.xticks(np.arange(0, 10, 1))
#       3 plt.yticks(np.arange(0, 19, 2))
#
# NameError: name 'x' is not defined

# %%
y2=np.arange(0,9)

# %%
x2=np.arange(0,9)

# %%
plt.plot(x, y2) #hata verir x ve y2 eleman sayısı eşit değil

# %%
plt.plot(y2,'r+');

# %%
plt.plot(x2,'r+');

# %%
print(plt.style.available)
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn-v0_8', 'seaborn-v0_8-bright', 'seaborn-v0_8-colorblind', 'seaborn-v0_8-dark', 'seaborn-v0_8-dark-palette', 'seaborn-v0_8-darkgrid', 'seaborn-v0_8-deep', 'seaborn-v0_8-muted', 'seaborn-v0_8-notebook', 'seaborn-v0_8-paper', 'seaborn-v0_8-pastel', 'seaborn-v0_8-poster', 'seaborn-v0_8-talk', 'seaborn-v0_8-ticks', 'seaborn-v0_8-white', 'seaborn-v0_8-whitegrid', 'tableau-colorblind10']

# %%
plt.style.use("classic")
plt.plot(x2, y2);

# %%
plt.figure(figsize=(10,5))
plt.plot(x2,y2)
plt.show()

# %%
# Grafiklere argüman verme

# %%
x=np.linspace(0,10,100)
y=np.sin(x)

plt.figure(figsize=(12,8))
plt.plot(x,y,"m4")
plt.show()

# %%
#0-10 arasında eşit aralıklı sayı üretti. 
# m=renk kodu 4= Marker stili kodudur ve "4" işaretçi stilini temsil eder, yani aşağıya bakan bir üçgen şeklindedir.

# %%
plt.figure(figsize=(12,8))
plt.plot(x,y,"g^")
plt.show()

# %%
plt.figure(figsize=(12,8))
plt.plot(x,y,"g^")
plt.show()

# %%
## Axis Name , Title

# %%
plt.figure(figsize=(12,8))
plt.plot(x,y,"r*")

plt.xlabel("X-Axis")
plt.ylabel("Y-Axis")

plt.title(label="AXES")
plt.show()

# %%
plt.figure(figsize=(12,8))
plt.plot(x,y,"b-.")

plt.xlabel("X-Axis")
plt.ylabel("Y-Axis")

plt.title(label="AXES")
plt.show()

# %%
plt.figure(figsize=(12,8))
plt.plot(x,y,"g:")

plt.xlabel("X-Axis")
plt.ylabel("Y-Axis")

plt.title(label="AXES")
plt.show()

# %%
plt.figure(figsize=(12,8))
plt.plot(x,y,"y--")

plt.xlabel("X-Axis")
plt.ylabel("Y-Axis")

plt.title(label="AXES")
plt.show()

# %%
age=np.arange(25,44,2.5)
salary1=np.arange(40000,76000,5000)
salary2=[45372,46852,69401,56790,73000,80000,83545,95653]

# %%
plt.plot(age,salary1,"b:",label="salary1")

# %%
#tek grafikte 2 tane line grafik nasıl olur

# %%
plt.plot(age,salary1,"b:",label="salary1")
plt.plot(age,salary2,"r-.",label="salary2")

# %%
#grafik başlığı ve axisleri yazma

# %%
plt.plot(age,salary1,"b:",label="salary1")
plt.plot(age,salary2,"r-.",label="salary2")

plt.xlabel("Age")
plt.ylabel("Salary")
plt.title("SALARY BY AGE")

plt.legend()
plt.show()

# %%
plt.plot(age,salary1,"g:",label="salary1")
plt.plot(age,salary2,"y-.",label="salary2")

plt.xlabel("Age")
plt.ylabel("Salary")
plt.title("SALARY BY AGE")

plt.legend(loc="lower right")
plt.show()

# %%
plt.figure(figsize=(10, 5))
plt.plot(age, salary1, "y:", label = "Salary1")
plt.plot(age, salary2, "m-", label = "Salary2")
plt.xlabel("Age")
plt.ylabel("Salary")
plt.title("SALARY BY AGE")
plt.legend(loc="upper right")
plt.show()

# %%
plt.figure(figsize=(10, 5))
plt.plot(age, salary1, "g:", label = "Salary1")
plt.plot(age, salary2, "m-", label = "Salary2")
plt.xlabel("Age")
plt.ylabel("Salary")
plt.title("SALARY BY AGE")
plt.legend(bbox_to_anchor=(0.5,0.5))
plt.show()

# %%
plt.figure(figsize=(10, 5))
plt.plot(age, salary1, "g:", label = "Salary1")
plt.plot(age, salary2, "m-", label = "Salary2")
plt.xlabel("Age")
plt.ylabel("Salary")
plt.title("SALARY BY AGE")
plt.legend(bbox_to_anchor=(0.55,1))
plt.show()

# %%
plt.figure(figsize=(10, 5))
plt.plot(age, salary1, "g:", label = "Salary1")
plt.plot(age, salary2, "m-", label = "Salary2")
plt.xlabel("Age")
plt.ylabel("Salary")
plt.title("SALARY BY AGE")
plt.legend(bbox_to_anchor=(0.5,0.5,0,1))
plt.show()

# %%
plt.plot(age, salary1, "g:", label = "Salary1")
plt.plot(age, salary2, "m-", label = "Salary2")
plt.xlabel("Age")
plt.ylabel("Salary")
plt.title("SALARY BY AGE")
plt.legend(bbox_to_anchor=(0.55,1,0.5,0.3))
plt.show()

# %%
plt.figure(figsize=(10, 5))
plt.plot(age, salary1, "g:", label = "Salary1")
plt.plot(age, salary2, "m-", label = "Salary2")
plt.xlabel("Age")
plt.ylabel("Salary")
plt.title("SALARY BY AGE")
plt.legend(bbox_to_anchor=(0.45, 0.1, 0.8, 0.1)) #İnce ayar yapmak için
plt.show()

# %%
plt.figure(figsize=(10, 5))
plt.plot(age, salary1, "y:", linewidth=6 , label = "Salary1")
plt.plot(age, salary2, "m-", lw = 10,label = "Salary2")
plt.xlabel("Age")
plt.ylabel("Salary")
plt.title("SALARY BY AGE")
plt.legend(bbox_to_anchor=(0.45, 0.1, 0.8, 0.1)) #İnce ayar yapmak için
plt.show()

# %%
# figure ve axes renklendirmesi

# %%
plt.figure(facecolor="yellow" , figsize=(10,5))
ax=plt.axes()
ax.set_facecolor("xkcd:mint green")
plt.plot(age, salary1, "y:", linewidth=6 , label = "Salary1")
plt.plot(age, salary2, "m-", lw = 10,label = "Salary2")
plt.xlabel("Age")
plt.ylabel("Salary")
plt.title("SALARY BY AGE")
plt.legend(loc="upper center") 
plt.show()

# %%
#functional method

# %%
plt.plot(age,salary1)
plt.xlabel("Age")
plt.ylabel("Salary")
plt.title("Salary by Age")

plt.show()

# %%
#object oriented method

# %%
fig,ax=plt.subplots()
ax.plot(age,salary1)
ax.set_xlabel("Age")
ax.set_ylabel("Salary")
ax.set_title("Salary by Age")

plt.show()

# %%
#functional method(çoklu grafik çizme)

# %%
plt.subplot(2,1,1)#2 satır 1 sütun 1.grafik
plt.plot(age,salary1, "r")

plt.subplot(2,1,2) #2.grafik
plt.plot(age,salary2, "y")

plt.show()

# %%
#object oriented method ile çoklu grafik

# %%
fig,ax=plt.subplots(2,1) #2satır 1 sütunlu grafik
ax[0].plot(age,salary1,"r") #1.satır
ax[1].plot(age,salary2,"y") #2.satır

plt.show()

# %%
fig,ax=plt.subplots(1,2) #1satır 2 sütunlu grafik
ax[0].plot(age,salary1,"r") #1.sütun
ax[1].plot(age,salary2,"y") #2.sütun

plt.show()

# %%
fig,ax=plt.subplots(1,2 , figsize=(10,5) ,facecolor="blue") #1satır 2 sütunlu grafik
ax[0].plot(age,salary1,"r") #1.sütun
ax[1].plot(age,salary2,"y") #2.sütun

plt.show()

# %%
fig,ax=plt.subplots(1,2 , figsize=(5,10) ,facecolor="m") #1satır 2 sütunlu grafik
ax[0].plot(age,salary1,"r") #1.sütun
ax[1].plot(age,salary2,"y") #2.sütun

plt.show()

# %%
#functional method(çoklu grafik çizme)

# %%
#3 sütun 2 satırdan oluşan toplam 6 grafik çizme

# %%
plt.subplot(2,3,1)
plt.plot(age,salary1,"r")

plt.subplot(2,3,2)
plt.plot(age,salary1,"r")

plt.subplot(2,3,3)
plt.plot(age,salary1,"r")

plt.subplot(2,3,4)
plt.plot(age,salary1,"b")

plt.subplot(2,3,5)
plt.plot(age,salary1,"b")

plt.subplot(2,3,6)
plt.plot(age,salary1,"b")

plt.show()

# %%
plt.subplot(2,3,1)
plt.plot(age,salary1,"r")

plt.subplot(2,3,2)
plt.plot(age,salary1,"r")

plt.subplot(2,3,3)
plt.plot(age,salary1,"r")

plt.subplot(2,3,4)
plt.plot(age,salary1,"b")

plt.subplot(2,3,5)
plt.plot(age,salary1,"b")

plt.subplot(2,3,6)
plt.plot(age,salary1,"b")

plt.tight_layout() #içiçe giren kısımları otomatik düzenler

plt.show()

# %%
#object oriented method ile çoklu grafik

# %%
fig,ax=plt.subplots(2,3 figsize = (10,10), facecolor="blue")
a[0][0].plot(age,salary1,"r")
a[0][1].plot(age,salary1,"r")
a[0][2].plot(age,salary1,"r")

a[1][0].plot(age,salary1,"b")
a[1][1].plot(age,salary1,"b")
a[1][2].plot(age,salary1,"b")

plt.tight_layout()

plt.show()
# Out:
#   Cell In[200], line 1
#     fig,ax=plt.subplots(2,3 figsize = (10,10), facecolor="blue")
#                           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
fig, ax = plt.subplots(2, 3)
ax[0][0].plot(age, salary1, "r")
ax[0][1].plot(age, salary1, "r")
ax[0][2].plot(age, salary1, "r")
ax[1][0].plot(age, salary1, "b")
ax[1][1].plot(age, salary1, "b")
ax[1][2].plot(age, salary1, "b")
plt.tight_layout() # içiçe giren kısımları otomatik düzneler
plt.show()

# %%
x = np.arange(0, 30, 0.2)
fig, ax = plt.subplots(figsize=(14, 8))
ax.plot(x, x-1, color = "r", linewidth = 1, linestyle = "-")
ax.plot(x, x-2, color = "green", lw = 2, ls = "-.")
ax.plot(x, x-3, color = "cyan", lw = 3, ls = ":")
ax.plot(x, x-4, color = "m", lw = 4, ls = "--")
plt.show()

# %%
x = np.arange(0, 10)
fig, ax = plt.subplots(2,2 , figsize=(12, 6))
ax[0,0].plot(x, "r", marker="+" , markersize="5")
ax[0,1].plot(x-2, "y", marker="o" , markersize="3")
ax[1,0].plot(x-3, "b", marker="s" , markersize="5")
ax[1,1].plot(x-4, "g", marker="1" , ms="5")
plt.show()

# %%
x = np.arange(0, 10)
fig, ax = plt.subplots(2, 2, figsize=(12, 6))
ax[0, 0].plot(x, "r", marker = "+", markersize = "5")
ax[0, 1].plot(x-2, "y", marker = "o", markersize = "3")
ax[1, 0].plot(x-3, "blue", marker = "s", markersize = "5")
ax[1, 1].plot(x-4, "g", marker = "1", ms = "5")
plt.show()

# %%
x = np.arange(0, 10)
fig, ax = plt.subplots(2, 2, figsize=(12, 6))
ax[0, 0].plot(x, "r", marker = "+", markersize = "5")
ax[0, 0].set_title("Grafik - 1", fontsize = 18)
ax[0, 0].set_xlabel("X-Label", fontsize = 14)
ax[0, 0].set_ylabel("Y-Label", fontsize = 14)
ax[0, 1].plot(x-2, "y", marker = "o", markersize = "3")
ax[0, 1].set_title("Grafik - 2", fontsize = 18)
ax[0, 1].set_xlabel("X-Label", fontsize = 14)
ax[0, 1].set_ylabel("Y-Label", fontsize = 14)
ax[1, 0].plot(x-3, "blue", marker = "s", markersize = "5")
ax[1, 0].set_title("Grafik - 3", fontsize = 18)
ax[1, 0].set_xlabel("X-Label", fontsize = 14)
ax[1, 0].set_ylabel("Y-Label", fontsize = 14)
ax[1, 1].plot(x-4, "g", marker = "1", ms = "5")
ax[1, 1].set_title("Grafik - 4", fontsize = 18)
ax[1, 1].set_xlabel("X-Label", fontsize = 14)
ax[1, 1].set_ylabel("Y-Label", fontsize = 14)
plt.tight_layout() # içiçe giren kısımları otomatik düzneler
plt.show()

# %%
x = np.arange(-50, 50)
y1 = np.power(x, 2)
y2 = np.power(x, 3)
y3 = np.sin(x)
y4 = np.cos(x)
y5 = np.tan(x)
y6 = np.tanh(x)
y7 = np.sinh(x)
y8 = np.cosh(x)
y9 = np.exp(x)
fig1, ax1 = plt.subplots(nrows = 3, ncols = 3, figsize= (20, 20))
ax1[0, 0].plot(x, y1, "tab:blue") # set the color of line chart
ax1[0, 0].set_title("Square Function") # setting title of subplot
ax1[0, 0].set_xlabel("X", fontsize = 18)
ax1[0, 0].set_ylabel("Y", fontsize = 18)
ax1[0, 1].plot(x, y2, "tab:orange") # set the color of line chart
ax1[0, 1].set_title("Cubic Function") # setting title of subplot
ax1[0, 1].set_xlabel("X", fontsize = 18)
ax1[0, 1].set_ylabel("Y", fontsize = 18)
ax1[0, 2].plot(x, y3, "tab:green") # set the color of line chart
ax1[0, 2].set_title("Sine Function") # setting title of subplot
ax1[0, 2].set_xlabel("X", fontsize = 18)
ax1[0, 2].set_ylabel("Y", fontsize = 18)
ax1[1, 0].plot(x, y4, "r-") # set the color of line chart
ax1[1, 0].set_title("Cosine Function") # setting title of subplot
ax1[1, 0].set_xlabel("X", fontsize = 18)
ax1[1, 0].set_ylabel("Y", fontsize = 18)
ax1[1, 1].plot(x, y5, "b-") # set the color of line chart
ax1[1, 1].set_title("Tangent Function") # setting title of subplot
ax1[1, 1].set_xlabel("X", fontsize = 18)
ax1[1, 1].set_ylabel("Y", fontsize = 18)
ax1[1, 2].plot(x, y6, "g-") # set the color of line chart
ax1[1, 2].set_title("Hyperbolic Tangent Function") # setting title of subplot
ax1[1, 2].set_xlabel("X", fontsize = 18)
ax1[1, 2].set_ylabel("Y", fontsize = 18)
ax1[2, 0].plot(x, y7, "m-") # set the color of line chart
ax1[2, 0].set_title("Hyperbolic Sine Function") # setting title of subplot
ax1[2, 0].set_xlabel("X", fontsize = 18)
ax1[2, 0].set_ylabel("Y", fontsize = 18)
ax1[2, 1].plot(x, y8, "y*") # set the color of line chart
ax1[2, 1].set_title("Hyperbolic Cosine Function") # setting title of subplot
ax1[2, 1].set_xlabel("X", fontsize = 18)
ax1[2, 1].set_ylabel("Y", fontsize = 18)
ax1[2, 2].plot(x, y9, "kv") # set the color of line chart
ax1[2, 2].set_title("Exp Function") # setting title of subplot
ax1[2, 2].set_xlabel("X", fontsize = 18)
ax1[2, 2].set_ylabel("Y", fontsize = 18)
plt.show()

# %%
## Default değerlere dönme

# %%
mpl.rcParams.update(mpl.rcParamsDefault)

# %%
x = np.arange(0, 30, 0.2)
fig, ax = plt.subplots(figsize=(14, 8))
ax.plot(x, x-1, color = "r", linewidth = 1, linestyle = "-")
ax.plot(x, x-2, color = "green", lw = 2, ls = "-.")
ax.plot(x, x-3, color = "cyan", lw = 3, ls = ":")
ax.plot(x, x-4, color = "m", lw = 4, ls = "--")
plt.show()

# %%
#Scatter Plot
